# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.__version__
# Out:
# '3.0.6'

# %%
df = pd.read_csv('car_fuel_efficiency_2026.csv')

# %%
df.shape
# Out:
# (10000, 11)

# %%
df['fuel_type'].nunique()
# Out:
# 3

# %%
(df.isna().sum() > 0).sum()
# Out:
# np.int64(2)

# %%
df.describe()
# Out:
#          model_year    num_doors  engine_displacement  num_cylinders  \
# count  10000.000000  10000.00000         10000.000000   10000.000000
# mean    1999.549500      3.50400          2268.807000       6.035200
# std       14.207925      0.95209           183.447355       0.542578
# min     1975.000000      2.00000          1590.000000       4.000000
# 25%     1987.000000      3.00000          2150.000000       6.000000
# 50%     2000.000000      4.00000          2270.000000       6.000000
# 75%     2012.000000      4.00000          2390.000000       6.000000
# max     2024.000000      5.00000          3110.000000       8.000000
#
#         horsepower  vehicle_weight  acceleration  fuel_efficiency_mpg
# count  9123.000000    10000.000000   9736.000000         10000.000000
# mean    254.446016     4286.754000     18.888044            29.997700
# std      22.844613      266.212491      1.279543             2.930245
# min     171.000000     3320.000000     14.000000            19.800000
# 25%     239.000000     4110.000000     18.000000            28.000000
# 50%     254.000000     4280.000000     18.900000            30.000000
# 75%     270.000000     4470.000000     19.700000            31.900000
# max     334.000000     5460.000000     23.800000            41.200000

# %%
df.columns
# Out:
# Index(['model_year', 'origin', 'fuel_type', 'drivetrain', 'num_doors',
#        'engine_displacement', 'num_cylinders', 'horsepower', 'vehicle_weight',
#        'acceleration', 'fuel_efficiency_mpg'],
#       dtype='str')

# %%
df.head(10)
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
# 5        2007     USA    Hybrid  Front-wheel drive          2
# 6        1992    Asia  Gasoline  Front-wheel drive          2
# 7        2005     USA  Gasoline  Front-wheel drive          4
# 8        1997    Asia  Gasoline   Rear-wheel drive          3
# 9        2004     USA    Diesel    All-wheel drive          5
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
# 5                 2290              6       266.0            4260
# 6                 2270              6       250.0            4310
# 7                 2370              6       279.0            4090
# 8                 2330              6       251.0            4230
# 9                 2330              6       280.0            4620
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# 4          17.5                 31.0
# 5          18.8                 31.2
# 6          21.7                 26.8
# 7          17.4                 30.2
# 8          19.5                 30.9
# 9          17.7                 31.2

# %%
df[df['origin'] == 'Asia']['fuel_efficiency_mpg'].max()
# Out:
# np.float64(41.2)

# %%
df['horsepower'].mean().round(2)
# Out:
# np.float64(254.45)

# %%
df['horsepower'].mode()[0]
# Out:
# np.float64(252.0)

# %%
df['horsepower'].value_counts()
# Out:
# horsepower
# 252.0    174
# 246.0    168
# 256.0    168
# 259.0    165
# 253.0    165
#         ...
# 322.0      1
# 330.0      1
# 175.0      1
# 178.0      1
# 320.0      1
# Name: count, Length: 153, dtype: int64

# %%
df['horsepower'] = df['horsepower'].fillna(252)

# %%
df.describe()
# Out:
#          model_year    num_doors  engine_displacement  num_cylinders  \
# count  10000.000000  10000.00000         10000.000000   10000.000000
# mean    1999.549500      3.50400          2268.807000       6.035200
# std       14.207925      0.95209           183.447355       0.542578
# min     1975.000000      2.00000          1590.000000       4.000000
# 25%     1987.000000      3.00000          2150.000000       6.000000
# 50%     2000.000000      4.00000          2270.000000       6.000000
# 75%     2012.000000      4.00000          2390.000000       6.000000
# max     2024.000000      5.00000          3110.000000       8.000000
#
#          horsepower  vehicle_weight  acceleration  fuel_efficiency_mpg
# count  10000.000000    10000.000000   9736.000000         10000.000000
# mean     254.231500     4286.754000     18.888044            29.997700
# std       21.830757      266.212491      1.279543             2.930245
# min      171.000000     3320.000000     14.000000            19.800000
# 25%      241.000000     4110.000000     18.000000            28.000000
# 50%      252.000000     4280.000000     18.900000            30.000000
# 75%      268.000000     4470.000000     19.700000            31.900000
# max      334.000000     5460.000000     23.800000            41.200000

# %%
X = df[df['origin'] == 'Asia'][['vehicle_weight','model_year']].head(7).values

# %%
X
# Out:
# array([[4240, 1996],
#        [4310, 1992],
#        [4230, 1997],
#        [4420, 1978],
#        [3950, 2007],
#        [4750, 2021],
#        [4450, 2019]])

# %%
XTX = X.T.dot(X)

# %%
XTX
# Out:
# array([[131950500,  60750580],
#        [ 60750580,  28041424]])

# %%
XTX_inv = np.linalg.inv(XTX)

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# %%
w = XTX_inv.dot(X.T).dot(y)

# %%
w
# Out:
# array([0.13644777, 0.2327492 ])

# %%
np.sum(w)
# Out:
# np.float64(0.36919696904925486)
